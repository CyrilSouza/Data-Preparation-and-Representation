# %%
from sklearn import tree
from pandas import read_csv
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
df= read_csv("AXISBANK.csv")

# %%
df
# Out:
#             Date    Symbol Series  Prev Close   Open    High     Low    Last  \
# 0     2000-01-03   UTIBANK     EQ       24.70   26.7   26.70   26.70   26.70
# 1     2000-01-04   UTIBANK     EQ       26.70   27.0   28.70   26.50   27.00
# 2     2000-01-05   UTIBANK     EQ       26.85   26.0   27.75   25.50   26.40
# 3     2000-01-06   UTIBANK     EQ       26.30   25.8   27.00   25.80   25.90
# 4     2000-01-07   UTIBANK     EQ       25.95   25.0   26.00   24.25   25.00
# ...          ...       ...    ...         ...    ...     ...     ...     ...
# 5301  2021-04-26  AXISBANK     EQ      671.35  694.0  703.80  684.50  699.50
# 5302  2021-04-27  AXISBANK     EQ      700.45  691.1  703.90  684.10  700.90
# 5303  2021-04-28  AXISBANK     EQ      699.55  708.0  712.50  688.15  705.95
# 5304  2021-04-29  AXISBANK     EQ      708.15  712.0  726.90  707.00  717.10
# 5305  2021-04-30  AXISBANK     EQ      719.40  705.0  729.85  705.00  711.65
#
# ...

# %%
df.hist()
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
df.plot.bar()
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
df1=read_csv("BAJAJFINSV.csv")
df1
# Out:
#             Date      Symbol Series  Prev Close      Open      High       Low  \
# 0     2008-05-26  BAJAJFINSV     EQ     2101.05    600.00    619.00    501.00
# 1     2008-05-27  BAJAJFINSV     EQ      509.10    505.00    610.95    491.10
# 2     2008-05-28  BAJAJFINSV     EQ      554.65    564.00    665.60    564.00
# 3     2008-05-29  BAJAJFINSV     EQ      640.95    656.65    703.00    608.00
# 4     2008-05-30  BAJAJFINSV     EQ      632.40    642.40    668.00    588.30
# ...          ...         ...    ...         ...       ...       ...       ...
# 3196  2021-04-26  BAJAJFINSV     EQ     9916.65   9992.00  10125.00   9902.20
# 3197  2021-04-27  BAJAJFINSV     EQ    10001.75  10000.00  10133.00   9964.70
# 3198  2021-04-28  BAJAJFINSV     EQ    10091.35  10200.00  10615.95  10151.15
# 3199  2021-04-29  BAJAJFINSV     EQ    10489.30  10540.00  11300.00  10520.00
# 3200  2021-04-30  BAJAJFINSV     EQ    11176.55  11000.00  11225.00  10868.70
#
# ...

# %%
df1.hist()
plt.show()

# %%
df1.plot.bar()
plt.show()

# %%
plt.scatter(df1['High'],df1['Low'])
plt.xlabel('High')
plt.ylabel('Low')
plt.title('Scatter plot on Bajaj Finance')
# Out:
# Text(0.5, 1.0, 'Scatter plot on Bajaj Finance')

# %%
plt.pie(df1['High'])
plt.show()

# %%
df2=read_csv("AXISBANK.csv")
x=np.array(df.drop(["Open"],1))
y=np.array(df["Open"])
# Out:
# C:\Users\Cyril\AppData\Local\Temp/ipykernel_6200/3335944372.py:2: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only
#   x=np.array(df.drop(["Open"],1))

# %%
x
# Out:
# array([['2000-01-03', 'UTIBANK', 'EQ', ..., nan, nan, nan],
#        ['2000-01-04', 'UTIBANK', 'EQ', ..., nan, nan, nan],
#        ['2000-01-05', 'UTIBANK', 'EQ', ..., nan, nan, nan],
#        ...,
#        ['2021-04-28', 'AXISBANK', 'EQ', ..., 507747.0, 17851331.0,
#         0.3302],
#        ['2021-04-29', 'AXISBANK', 'EQ', ..., 312079.0, 7357520.0, 0.2836],
#        ['2021-04-30', 'AXISBANK', 'EQ', ..., 232879.0, 6786072.0, 0.2949]],
#       dtype=object)

# %%
dropedDF=df2.dropna()

# %%
dropedDF
# Out:
#             Date    Symbol Series  Prev Close     Open     High      Low  \
# 2850  2011-06-01  AXISBANK     EQ     1282.50  1282.25  1291.75  1265.20
# 2851  2011-06-02  AXISBANK     EQ     1278.25  1255.10  1285.00  1255.10
# 2852  2011-06-03  AXISBANK     EQ     1273.75  1272.00  1288.00  1224.00
# 2853  2011-06-06  AXISBANK     EQ     1242.75  1242.00  1242.00  1208.15
# 2854  2011-06-07  AXISBANK     EQ     1235.45  1227.00  1252.90  1224.75
# ...          ...       ...    ...         ...      ...      ...      ...
# 5301  2021-04-26  AXISBANK     EQ      671.35   694.00   703.80   684.50
# 5302  2021-04-27  AXISBANK     EQ      700.45   691.10   703.90   684.10
# 5303  2021-04-28  AXISBANK     EQ      699.55   708.00   712.50   688.15
# 5304  2021-04-29  AXISBANK     EQ      708.15   712.00   726.90   707.00
# 5305  2021-04-30  AXISBANK     EQ      719.40   705.00   729.85   705.00
#
#          Last    Close     VWAP    Volume      Turnover    Trades  \
# ...
